# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
# !pip uninstall setuptools -y
# !pip install setuptools
# Out:
# WARNING: Skipping setuptools as it is not installed.
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools
# Successfully installed setuptools-80.9.0
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file("output.html")
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 409.67it/s]00:00, 13.01it/s, Describe variable: Embarked]
# Summarize dataset: 100%|██████████| 47/47 [00:02<00:00, 16.31it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.23s/it]
# Render HTML: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 74.75it/s]
