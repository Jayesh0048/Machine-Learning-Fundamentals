# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Creating a DataFrames

# %%
# Using List
student_data = [[100,80,10,0],[90,70,7,0],[80,60,6,0],[70,50,5,0],[60,40,4,0]]
student_df = pd.DataFrame(student_data, columns=['iq','Marks','package','year'])
student_df
# Out:
#     iq  Marks  package  year
# 0  100     80       10     0
# 1   90     70        7     0
# 2   80     60        6     0
# 3   70     50        5     0
# 4   60     40        4     0

# %%
# using Dictionary
student_data = {'name':['Alice','Bob','Charlie','David','Eve'],
                'iq':[100,90,80,70,60],
                'Marks':[80,70,60,50,40],
                'package':[10,7,6,5,4]}
student_df = pd.DataFrame(student_data)
student_df.set_index('name', inplace=True)
student_df
# Out:
#           iq  Marks  package
# name
# Alice    100     80       10
# Bob       90     70        7
# Charlie   80     60        6
# David     70     50        5
# Eve       60     40        4

# %%
# using read_csv
movies = pd.read_csv('movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# DataFrames Attributes and mathods

# %%
# shape
movies.shape
ipl.shape
# Out:
# (950, 20)

# %%
# dtypes
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
# index
movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# vaLues
movies.values
students = student_df.values
students
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [ 80,  60,   6],
#        [ 70,  50,   5],
#        [ 60,  40,   4]])

# %%
movies.head
# Out:
# <bound method NDFrame.head of                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl.tail
# Out:
# <bound method NDFrame.tail of           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# ...

# %%
# sample
movies.sample(5)
# Out:
#                         title_x    imdb_id  \
# 859              Bumm Bumm Bole  tt1629241
# 1041  Wafa: A Deadly Love Story  tt1372304
# 1567                     Lagaan  tt0169102
# 59             Bala (2019 film)  tt9420648
# 438        Meeruthiya Gangsters  tt4117066
#
#                                             poster_path  \
# 859   https://upload.wikimedia.org/wikipedia/en/thum...
# 1041  https://upload.wikimedia.org/wikipedia/en/thum...
# 1567  https://upload.wikimedia.org/wikipedia/en/thum...
# 59    https://upload.wikimedia.org/wikipedia/en/thum...
# 438   https://upload.wikimedia.org/wikipedia/commons...
#
#                                               wiki_link  \
# 859        https://en.wikipedia.org/wiki/Bumm_Bumm_Bole
# 1041  https://en.wikipedia.org/wiki/Wafa:_A_Deadly_L...
# 1567               https://en.wikipedia.org/wiki/Lagaan
# 59       https://en.wikipedia.org/wiki/Bala_(2019_film)
# 438   https://en.wikipedia.org/wiki/Meeruthiya_Gangster
#
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#duplicates
movies.duplicated().sum()
ipl.duplicated().sum()
student_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# rename
student_df.rename(columns={'iq':'IQ Score','Marks':'Marks Obtained','package':'Package in LPA'}, inplace=True)
student_df
# Out:
#          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Bob            90              70               7
# Charlie        80              60               6
# David          70              50               5
# Eve            60              40               4

# %% [markdown]
# Math Methods

# %%
#sum
movies.sum
# Out:
# <bound method DataFrame.sum of                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
student_df.sum(axis=1)
# Out:
# name
# Alice      190
# Bob        167
# Charlie    146
# David      125
# Eve        104
# dtype: int64

# %%
student_df.mean
# Out:
# <bound method DataFrame.mean of          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Bob            90              70               7
# Charlie        80              60               6
# David          70              50               5
# Eve            60              40               4>

# %%
student_df.min()
# Out:
# IQ Score          60
# Marks Obtained    40
# Package in LPA     4
# dtype: int64

# %%
student_df.std
# Out:
# <bound method DataFrame.std of          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Bob            90              70               7
# Charlie        80              60               6
# David          70              50               5
# Eve            60              40               4>

# %%
student_df.max()
# Out:
# IQ Score          100
# Marks Obtained     80
# Package in LPA     10
# dtype: int64

# %%
student_df.var()
# Out:
# IQ Score          250.0
# Marks Obtained    250.0
# Package in LPA      5.3
# dtype: float64

# %% [markdown]
# Selecting cols from a DataFrame

# %%
# single Col
type(movies['title_x'])
# Out:
# pandas.core.series.Series

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple Col
type(movies[['title_x','actors','year_of_release']])
# Out:
# pandas.core.frame.DataFrame

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# Selecting a Rows from a Dataframe
#
#
#   1.iloc- Searches using index positions
#
#   2.loc- searches using index labels

# %%
# single Row
movies.iloc[3]
# Out:
# title_x                                               Why Cheat India
# imdb_id                                                     tt8108208
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link               https://en.wikipedia.org/wiki/Why_Cheat_India
# title_y                                               Why Cheat India
# original_title                                        Why Cheat India
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           121
# genres                                                    Crime|Drama
# imdb_rating                                                       6.0
# imdb_votes                                                       1891
# story               The movie focuses on existing malpractices in ...
# ...

# %%
# multiple Rows
movies.iloc[:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# fancy indexing
movies.iloc[[1,3,5,7,9]]
# Out:
#             title_x    imdb_id  \
# 1     Battalion 609  tt9472208
# 3   Why Cheat India  tt8108208
# 5       Soni (film)  tt6078866
# 7        Bombairiya  tt4971258
# 9  Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 1                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# 9  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link          title_y  \
# 1     https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3   https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 5       https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 7        https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
# 9  https://en.wikipedia.org/wiki/Thackeray_(film)        Thackeray
#
# ...

# %%
# loc
student_df
# Out:
#          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Bob            90              70               7
# Charlie        80              60               6
# David          70              50               5
# Eve            60              40               4

# %%
student_df.loc['Alice':'Eve':2]
# Out:
#          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Charlie        80              60               6
# Eve            60              40               4

# %%
student_df.loc[['Alice','Charlie','Eve']]
# Out:
#          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Charlie        80              60               6
# Eve            60              40               4

# %%
student_df.iloc[[0,2,4]]
# Out:
#          IQ Score  Marks Obtained  Package in LPA
# name
# Alice         100              80              10
# Charlie        80              60               6
# Eve            60              40               4

# %% [markdown]
# Selecting Both rows and Cols

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:3, ['title_x','year_of_release','imdb_rating']]
# Out:
#                                 title_x  year_of_release  imdb_rating
# 0              Uri: The Surgical Strike             2019          8.4
# 1                         Battalion 609             2019          4.1
# 2  The Accidental Prime Minister (film)             2019          6.1
# 3                       Why Cheat India             2019          6.0

# %% [markdown]
# Filtering a DataFroame

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners
mask = ipl ['MatchNumber'] == 'Final'
new_df = ipl[mask]
new_df[["Season", "WinningTeam"]]

ipl[ipl['MatchNumber'] == 'Final'][["Season", "WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over fineshes have occured in IPL history
ipl[ipl['SuperOver'] == 'Y'].shape[0]
ipl[ipl['SuperOver'] == 'Y']
# Out:
#           ID       City        Date   Season MatchNumber  \
# 114  1254077    Chennai  2021-04-25     2021          20
# 158  1216512  Abu Dhabi  2020-10-18  2020/21          35
# 159  1216517        NaN  2020-10-18  2020/21          36
# 184  1216547        NaN  2020-09-28  2020/21          10
# 192  1216493        NaN  2020-09-20  2020/21           2
# 203  1178426     Mumbai  2019-05-02     2019          51
# 244  1175365      Delhi  2019-03-30     2019          10
# 339  1082625     Rajkot  2017-04-29     2017          35
# 474   829741  Ahmedabad  2015-04-21     2015          18
# 533   729315  Abu Dhabi  2014-04-29     2014          19
# 608   598017  Bangalore  2013-04-16     2013          21
# 621   598004  Hyderabad  2013-04-07     2013           7
# 819   419121    Chennai  2010-03-21  2009/10          16
# 883   392190  Cape Town  2009-04-23     2009          10
#
#                            Team1                        Team2  \
# ...

# %%
# how many matches had csk won in kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super kings')].shape[0]
# Out:
# 0

# %%
# toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votess>10000
movies[(movies['imdb_rating'] > 8.2) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 9

# %%
# action movies with rating higher than 7.5
mask1 = movies['genres'].str.split('|').apply(lambda x: 'Romance' in x)
mask2 = movies['imdb_rating'] > 7.5
movies[mask1 & mask2]
# Out:
#                         title_x     imdb_id  \
# 57       P Se Pyaar F Se Faraar  tt10816510
# 129     Laila Majnu (2018 film)   tt8011276
# 241     Shaadi Mein Zaroor Aana   tt7469726
# 275               Kapoor & Sons   tt4900716
# 347                Dear Zindagi   tt5946128
# 357     Tanu Weds Manu: Returns   tt2140465
# 358     Tanu Weds Manu: Returns   tt2140465
# 465   Highway (2014 Hindi film)   tt2980794
# 582                Bloody Isshq   tt2404187
# 606                  Raanjhanaa   tt2359810
# 635                The Lunchbox   tt2350496
# 678                 Vicky Donor   tt2317337
# 709                      Barfi!   tt2082197
# 770          Pyaar Ka Punchnama   tt1926313
# 847           The Japanese Wife   tt1620620
# 960                 Wake Up Sid   tt1324059
# 1087                 Jab We Met   tt1093370
# 1183       Lage Raho Munna Bhai   tt0456144
# 1361             Lakshya (film)   tt0323013
# 1378            Raincoat (film)   tt0405266
# ...

# %% [markdown]
# Adding New Cols

# %%
# completely New

movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# From existing ones
# movies.dropna(inplace=True)
# movies['Lead actor'] = movies['actors'].str.split('|').apply(lambda x: x[0])

# %% [markdown]
# Important DataFrame Functions

# %%
# astype
ipl.info()
#movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# # 2nd Session on Pandas

# %%
# value_counts
import numpy as np 
import pandas as pd

# %%
# value_counts (series and DataFrames)

marks = pd.DataFrame([
    [100,80,50],
    [59,45,78],
    [67,78,56],
    [78,89,67],
    [97,68,45]
],columns = ['iq', 'marks','package'])

marks
# Out:
#     iq  marks  package
# 0  100     80       50
# 1   59     45       78
# 2   67     78       56
# 3   78     89       67
# 4   97     68       45

# %%
marks.value_counts()
# Out:
# iq   marks  package
# 59   45     78         1
# 67   78     56         1
# 78   89     67         1
# 97   68     45         1
# 100  80     50         1
# Name: count, dtype: int64

# %%
# find which player has won most postm -> in final and qualifier

ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
# toss decision plot
ipl["TossDecision"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches each team has played
(ipl['Team2'].value_counts() + ipl['Team1'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
# sort values (series and dataframe) -> asending -> na_position -> inplace -> multiple cols

x = pd.Series([12,13,14,15,16,17])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    17
# dtype: int64

# %%
x.sort_values
# Out:
# <bound method Series.sort_values of 0    12
# 1    13
# 2    14
# 3    15
# 4    16
# 5    17
# dtype: int64>

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.sort_values('title_x',ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# rank(series) not Applicable on Frames
batsmen = pd.read_csv('batsman_runs_ipl.csv')
batsmen.sample(5)
# Out:
#             batter  batsman_run
# 72   Anureet Singh           36
# 318    MDKJ Perera           14
# 401   PWH de Silva           39
# 289      LPC Silva           40
# 23      AB Agarkar          179

# %%
batsmen['batting_rank'] = batsmen['batsman_run'].rank().rank(ascending=False)
batsmen.sort_values('batting_rank')
# Out:
#              batter  batsman_run  batting_rank
# 569         V Kohli        605.0           1.0
# 462        S Dhawan        604.0           2.0
# 130       DA Warner        603.0           3.0
# 430       RG Sharma        602.0           4.0
# 493        SK Raina        601.0           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh         12.0         594.0
# 63     Abdur Razzak         12.0         594.0
# 562          U Kaul         12.0         594.0
# 65       Akash Deep         12.0         594.0
# 57           AS Roy         12.0         594.0
#
# [605 rows x 3 columns]

# %%
# sort_index(series and dataframes)
marks = {
    'maths':67,
    'english':56,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks)
marks_series
# Out:
# maths       67
# english     56
# science     89
# hindi      100
# dtype: int64

# %%
marks_series.sort_index(ascending=False)
# Out:
# science     89
# maths       67
# hindi      100
# english     56
# dtype: int64

# %%
# set_index (dataframe)  --> inplace

batsmen
# Out:
#              batter  batsman_run  batting_rank
# 0    A Ashish Reddy        439.5         166.5
# 1          A Badoni        380.0         226.0
# 2        A Chandila         71.0         535.0
# 3          A Chopra        277.0         329.0
# 4       A Choudhary        203.5         402.5
# ..              ...          ...           ...
# 600      Yash Dayal         12.0         594.0
# 601   Yashpal Singh        263.0         343.0
# 602     Younis Khan         58.5         547.5
# 603    Yuvraj Singh        579.0          27.0
# 604          Z Khan        350.0         256.0
#
# [605 rows x 3 columns]

# %%
batsmen.set_index('batter',inplace= True)

# %%
batsmen
# Out:
#                 batsman_run  batting_rank
# batter
# A Ashish Reddy        439.5         166.5
# A Badoni              380.0         226.0
# A Chandila             71.0         535.0
# A Chopra              277.0         329.0
# A Choudhary           203.5         402.5
# ...                     ...           ...
# Yash Dayal             12.0         594.0
# Yashpal Singh         263.0         343.0
# Younis Khan            58.5         547.5
# Yuvraj Singh          579.0          27.0
# Z Khan                350.0         256.0
#
# [605 rows x 2 columns]

# %%
# reset_index (series + dataframe) -> drop parameter
batsmen.reset_index().set_index('batting_rank')
# Out:
#               index          batter  batsman_run
# batting_rank
# 166.5             0  A Ashish Reddy        439.5
# 226.0             1        A Badoni        380.0
# 535.0             2      A Chandila         71.0
# 329.0             3        A Chopra        277.0
# 402.5             4     A Choudhary        203.5
# ...             ...             ...          ...
# 594.0           600      Yash Dayal         12.0
# 343.0           601   Yashpal Singh        263.0
# 547.5           602     Younis Khan         58.5
# 27.0            603    Yuvraj Singh        579.0
# 256.0           604          Z Khan        350.0
#
# [605 rows x 3 columns]

# %%
batsmen.set_index('batting_rank')
# Out:
#                       batter  batsman_run
# batting_rank
# 166.5         A Ashish Reddy        439.5
# 226.0               A Badoni        380.0
# 535.0             A Chandila         71.0
# 329.0               A Chopra        277.0
# 402.5            A Choudhary        203.5
# ...                      ...          ...
# 594.0             Yash Dayal         12.0
# 343.0          Yashpal Singh        263.0
# 547.5            Younis Khan         58.5
# 27.0            Yuvraj Singh        579.0
# 256.0                 Z Khan        350.0
#
# [605 rows x 2 columns]

# %%
# series to datafrmae using reset_index
marks_series.reset_index()
# Out:
#      index    0
# 0    maths   67
# 1  english   56
# 2  science   89
# 3    hindi  100
